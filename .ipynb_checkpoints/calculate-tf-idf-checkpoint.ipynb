# %%
import math
from textblob import TextBlob as tb
import newspaper
import os
import random
import pickle

def tf(word, blob):
    return blob.words.count(word) / len(blob.words)

def n_containing(word, bloblist):
    return sum(1 for blob in bloblist if word in blob.words)

def idf(word, bloblist):
    return math.log(len(bloblist) / (1 + n_containing(word, bloblist)))

def tfidf(word, blob, bloblist):
    return tf(word, blob) * idf(word, bloblist)
# Out:
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/rabbi/.local/lib/python3.5/site-packages/requests/__init__.py:83: RequestsDependencyWarning: Old version of cryptography ([1, 2, 3]) may cause slowdown.
#   warnings.warn(warning, RequestsDependencyWarning)

# %%
cwd=os.getcwd()+'/'
news_path='bdnews_data.pkl'
with open(news_path, 'rb') as input:
    allnews = pickle.load(input)

# %%
bloblist=[]
for article in allnews.articles:
    if(article is not None):
        bloblist.append(tb(article.text))

# %%
searched_word='tangail'

# %%
for article in allnews.articles:
    if searched_word in article.title.lower():
        print(article.title)
        my_blob=tb(article.text)
        
        for my_word in my_blob.words:
            print(my_word+" "+str(tfidf(my_word, my_blob, bloblist)))
# Out:
# A year after Rupa murder, another gang-rape on moving bus alleged in Tangail
# Police 0.07322899446253488
# are 0.004848731020133769
# now 0.014004990864258821
# looking 0.012385937152630123
# for 0.0015174975443455418
# the 0.003418293797699037
# driver 0.017447997011667726
# ‘ 0.022326434560575797
# Alam 0.04304732932813659
# ’ 0.014823484971804092
# and 0.0010485593168109172
# supervisor 0.02400308229229389
# ‘ 0.022326434560575797
# Bishu 0.051456931462104075
# ’ 0.014823484971804092
# after 0.009015962624149432
# arresting 0.022778903260584186
# ‘ 0.022326434560575797
# Nazmul 0.061192678446406724
# ’ 0.014823484971804092
# 22 0.013198938160131013
# The 0.011580647067660592
# alleged 0.012479464415263208
# rape 0.03489599402333545
# incident 0.012479464415263208
# took 0.008235385457974117
# place 0.009390370783846459
# when 0.0046850296086103325
# the 0.003418293797699037
# woman 0.05468895494027255
# believed 0.01449843454119987
# to 0.001718391878198466
# have 0.0020333827363239647
# mental 0.038656272766135785
# disability 0.02400308229229389
# was 0.0027316739695401058
# on 0.0025943329655892886
# her 0.015238950953012814
# way 0.00830572291308565
# from 0.0029425180715450397
# Tangail 0.10291386292420815
# to 0.001718391878198466
# Bangabandhu 0.029961368531821048
# Bridge 0.037759587526494706
# East 0.029306380947683786
# area 0.010914678116857604
# in 0.0018155330793132927
# the 0.003418293797699037
# wee 0.022778903260584186
# hours 0.01203112179544267
# of 0.001210355386208862
# Friday 0.018599657325588367
# police 0.06287669382998601
# said 0.006912393211936743
# The 0.011580647067660592
# 25-year-old 0.021053519821826037
# woman 0.05468895494027255
# was 0.0027316739695401058
# alone 0.015722613572909577
# on 0.0025943329655892886
# the 0.003418293797699037
# bus 0.0477906938783385
# after 0.009015962624149432
# other 0.004308463318170114
# passengers 0.014204847854021355
# got 0.01104766766368358
# off 0.008098105193215728
# Bangabandhu 0.029961368531821048
# Bridge 0.037759587526494706
# East 0.029306380947683786
# Police 0.07322899446253488
# Station 0.01552465605956961
# OC 0.03965868158023266
# Mosharraf 0.037759587526494706
# Hossain 0.011473554721372866
# said 0.006912393211936743
# A 0.02093529005496505
# police 0.06287669382998601
# patrol 0.02400308229229389
# chased 0.021829356233715208
# the 0.003418293797699037
# bus 0.0477906938783385
# after 0.009015962624149432
# hearing 0.017154410324489208
# the 0.003418293797699037
# woman 0.05468895494027255
# crying 0.021829356233715208
# and 0.0010485593168109172
# caught 0.015335499623097977
# Nazmul 0.061192678446406724
# in 0.0018155330793132927
# the 0.003418293797699037
# act 0.01449843454119987
# while 0.005707123088678387
# Alam 0.04304732932813659
# and 0.0010485593168109172
